# %% [markdown]
# # 🔍 RipCatch Model Comparison (v1.0 vs v1.1 vs v2.0)
#
# This notebook compares different versions of the RipCatch model:
# - **v1.0**: Initial baseline model
# - **v1.1**: Improved with better augmentation
# - **v2.0**: Current state-of-the-art (YOLOv8m, mAP@50: 88.64%)
#
# We'll use MLflow to:
# - Load models from different experiment runs
# - Compare performance metrics side-by-side
# - Visualize improvements over versions
# - Generate comprehensive comparison reports
# - Analyze performance on different beach conditions

# %%
import sys
from pathlib import Path
sys.path.append(str(Path().absolute().parent))

from mlflow_integration.model_evaluation import RipCatchEvaluator
from mlflow_integration.experiment_tracking import ExperimentManager
import mlflow
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Setup
sns.set_style("whitegrid")
mlflow.set_tracking_uri("./mlruns")

print("✅ Imports complete. Ready for model comparison!")
